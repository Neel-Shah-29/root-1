# %%
import ROOT
from ROOT import TMVA 
import os
from array import array

# %%
ROOT.TMVA.Tools.Instance()
TMVA.PyMethodBase.PyInitialize()

## For PYMVA methods
TMVA.PyMethodBase.PyInitialize();


outputFile = ROOT.TFile.Open("BatchdataOutput.root", "RECREATE")

# %%
inputFileName = "images_data.root"
inputFile = ROOT.TFile.Open(inputFileName)

# %%
signalTree     = inputFile.Get("sig_tree")
backgroundTree = inputFile.Get("bkg_tree")

signalTree.Print()
# Out:
# ******************************************************************************
# *Tree    :sig_tree  : signal_tree                                            *
# *Entries :    10000 : Total =         2601382 bytes  File  Size =    2572423 *
# *        :          : Tree compression factor =   1.00                       *
# ******************************************************************************
# *Br    0 :var0      : var0/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    1 :var1      : var1/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    2 :var2      : var2/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    3 :var3      : var3/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    4 :var4      : var4/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    5 :var5      : var5/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    6 :var6      : var6/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    7 :var7      : var7/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    8 :var8      : var8/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br    9 :var9      : var9/F                                                 *
# *Entries :    10000 : Total  Size=      40631 bytes  File Size  =      40150 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   10 :var10     : var10/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   11 :var11     : var11/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   12 :var12     : var12/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   13 :var13     : var13/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   14 :var14     : var14/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   15 :var15     : var15/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   16 :var16     : var16/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   17 :var17     : var17/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   18 :var18     : var18/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   19 :var19     : var19/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   20 :var20     : var20/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   21 :var21     : var21/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   22 :var22     : var22/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   23 :var23     : var23/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   24 :var24     : var24/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   25 :var25     : var25/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   26 :var26     : var26/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   27 :var27     : var27/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   28 :var28     : var28/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   29 :var29     : var29/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   30 :var30     : var30/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   31 :var31     : var31/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   32 :var32     : var32/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   33 :var33     : var33/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   34 :var34     : var34/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   35 :var35     : var35/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   36 :var36     : var36/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   37 :var37     : var37/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   38 :var38     : var38/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   39 :var39     : var39/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   40 :var40     : var40/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   41 :var41     : var41/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   42 :var42     : var42/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   43 :var43     : var43/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   44 :var44     : var44/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   45 :var45     : var45/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   46 :var46     : var46/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   47 :var47     : var47/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   48 :var48     : var48/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   49 :var49     : var49/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   50 :var50     : var50/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   51 :var51     : var51/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   52 :var52     : var52/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   53 :var53     : var53/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   54 :var54     : var54/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   55 :var55     : var55/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   56 :var56     : var56/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   57 :var57     : var57/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   58 :var58     : var58/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   59 :var59     : var59/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   60 :var60     : var60/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   61 :var61     : var61/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   62 :var62     : var62/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*
# *Br   63 :var63     : var63/F                                                *
# *Entries :    10000 : Total  Size=      40637 bytes  File Size  =      40152 *
# *Baskets :        2 : Basket Size=      32000 bytes  Compression=   1.00     *
# *............................................................................*

# %%
df = ROOT.RDataFrame("sig_tree", "images_data.root")

# %%
# Take all columns
npy1 = df.AsNumpy()
print(npy1)
# Out:
# {'var0': ndarray([-1.336025  , -4.092883  ,  1.9655609 , ...,  0.30705032,
#          -7.390489  , -0.18619043], dtype=float32), 'var1': ndarray([0.7632829, 5.66362  , 1.4061441, ..., 8.663832 , 4.4268465,
#          1.2475878], dtype=float32), 'var10': ndarray([ 7.2729025,  5.52698  , 10.708342 , ...,  8.666056 ,  4.5726047,
#           3.7106621], dtype=float32), 'var11': ndarray([ 2.2186801, 11.85489  ,  9.511338 , ...,  6.8072405,  3.1950352,
#           5.3341336], dtype=float32), 'var12': ndarray([ 4.300408 ,  3.502065 , 18.303375 , ...,  1.0917444,  9.506968 ,
#           6.520689 ], dtype=float32), 'var13': ndarray([ 1.4888293, 12.501126 , 26.053385 , ...,  7.670646 ,  7.9255195,
#           1.824293 ], dtype=float32), 'var14': ndarray([-0.04247092,  7.6925483 , 13.814523  , ...,  2.071961  ,
#           3.499362  , -4.3938446 ], dtype=float32), 'var15': ndarray([ 2.5431843,  4.5940566, 11.517784 , ...,  2.3652434,  4.5096498,
#           2.0963604], dtype=float32), 'var16': ndarray([ 4.5934024,  5.1374154, -0.7009396, ..., -4.6060314,  1.0777992,
#           2.4875016], dtype=float32), 'var17': ndarray([ 6.7216744 ,  5.0386577 ,  5.3372765 , ...,  9.052116  ,
#          -0.21040355,  0.7110992 ], dtype=float32), 'var18': ndarray([ 1.45166674e+01, -1.15846712e-02,  1.06608543e+01, ...,
#           4.78129721e+00,  6.08987427e+00,  1.31810465e+01], dtype=float32), 'var19': ndarray([ 0.8974665, 16.34351  , 18.350018 , ..., 10.201735 ,  5.2978563,
#           7.02232  ], dtype=float32), 'var2': ndarray([ 3.082547  , -1.8811955 ,  4.5406365 , ...,  3.6843252 ,
#           5.5426073 ,  0.95661587], dtype=float32), 'var20': ndarray([ 7.6656237,  6.6695085, 21.871983 , ...,  7.4573965,  8.22809  ,
#           3.8029487], dtype=float32), 'var21': ndarray([ 4.5377865, 13.321091 , 13.502982 , ...,  6.44812  ,  5.770054 ,
#           6.570596 ], dtype=float32), 'var22': ndarray([ 7.8818445, 13.292504 , 21.026472 , ...,  0.9398442,  4.799359 ,
#           6.414047 ], dtype=float32), 'var23': ndarray([9.744052 , 5.447037 , 9.849641 , ..., 2.8422914, 4.173781 ,
#          1.013409 ], dtype=float32), 'var24': ndarray([0.4619083 , 4.2170305 , 2.4313707 , ..., 4.645605  , 0.47575527,
#          2.3073063 ], dtype=float32), 'var25': ndarray([ 3.8269534 ,  0.88509136, -0.49078315, ...,  8.448209  ,
#           6.357229  ,  4.8478045 ], dtype=float32), 'var26': ndarray([11.402901  ,  5.2208014 , 12.033975  , ..., 11.65134   ,
#           0.14490652, 14.661985  ], dtype=float32), 'var27': ndarray([17.011309 , 10.464975 ,  1.4349749, ..., 16.07756  , 13.834941 ,
#           7.18594  ], dtype=float32), 'var28': ndarray([16.552233 , 12.072972 , 14.66012  , ...,  7.9293494, 21.146132 ,
#          22.016205 ], dtype=float32), 'var29': ndarray([ 7.2027435, 13.669154 , 18.890951 , ..., 10.58407  , 16.882498 ,
#          14.463    ], dtype=float32), 'var3': ndarray([ 0.815374 , -0.5492171, -0.389066 , ...,  8.83163  , -1.3732111,
#          -0.5097652], dtype=float32), 'var30': ndarray([ 3.0213952, 13.450717 , 16.286842 , ...,  5.6263537, 14.795311 ,
#          20.308405 ], dtype=float32), 'var31': ndarray([ 6.5347047,  6.663485 ,  9.675058 , ..., -1.176807 ,  7.033725 ,
#           3.008607 ], dtype=float32), 'var32': ndarray([1.2906672 , 2.28304   , 0.63402075, ..., 1.2874488 , 1.4317615 ,
#          3.9267457 ], dtype=float32), 'var33': ndarray([ 6.190936 ,  3.7452757,  5.912916 , ..., 10.860844 ,  4.8335176,
#           4.7470236], dtype=float32), 'var34': ndarray([11.186904  ,  8.87229   ,  0.72995484, ...,  1.8830576 ,
#           4.999525  , 12.3142185 ], dtype=float32), 'var35': ndarray([19.657343 ,  3.6865606, 15.7146845, ..., 11.795384 ,  5.9204516,
#          11.231994 ], dtype=float32), 'var36': ndarray([14.433575, 18.267435,  9.263986, ...,  9.109113, 14.122816,
#          17.429863], dtype=float32), 'var37': ndarray([10.888389, 19.185621, 10.288151, ..., 19.133831, 14.968486,
#          11.389742], dtype=float32), 'var38': ndarray([17.552488, 14.8517  , 20.258608, ..., 11.065322, 20.200392,
#          21.122633], dtype=float32), 'var39': ndarray([ 2.4140606 ,  7.3459044 ,  9.887703  , ..., 11.76596   ,
#          11.211064  , -0.20612025], dtype=float32), 'var4': ndarray([ 3.816624 ,  4.2820153, 16.960608 , ..., -1.1845398,  2.5057364,
#           7.273461 ], dtype=float32), 'var40': ndarray([-2.2542386, -5.478763 , -0.6735108, ...,  3.9522007,  0.7586168,
#           1.8562311], dtype=float32), 'var41': ndarray([17.0368   ,  2.747641 ,  1.8451837, ..., 14.142555 ,  6.2215433,
#          12.324029 ], dtype=float32), 'var42': ndarray([12.252255 , 10.42547  ,  2.5282896, ...,  8.717794 , 10.860431 ,
#          16.143742 ], dtype=float32), 'var43': ndarray([14.978712, 17.631714,  6.548803, ..., 18.751064, 18.609547,
#          18.085646], dtype=float32), 'var44': ndarray([14.586638, 16.55819 ,  7.804596, ..., 11.829261, 13.799384,
#          10.81528 ], dtype=float32), 'var45': ndarray([21.267786 , 13.749073 , 11.436609 , ..., 17.216543 , 14.3919115,
#          11.037644 ], dtype=float32), 'var46': ndarray([14.311243 , 13.204224 ,  1.6657572, ...,  8.285822 , 13.701776 ,
#          13.445847 ], dtype=float32), 'var47': ndarray([ 1.0875026, 10.274003 ,  6.923444 , ...,  7.813322 ,  7.24126  ,
#           6.1429133], dtype=float32), 'var48': ndarray([-1.1829392, -2.7993786,  2.5780184, ...,  7.1785984,  5.260079 ,
#           2.067008 ], dtype=float32), 'var49': ndarray([-0.09062699,  3.322676  , -3.054891  , ...,  8.187037  ,
#           9.28487   , -0.7289648 ], dtype=float32), 'var5': ndarray([ 3.7842727,  0.052626 , 18.151186 , ...,  2.033194 ,  7.8011622,
#          -2.0022192], dtype=float32), 'var50': ndarray([12.282044 , 13.374023 ,  6.3015547, ...,  9.659966 ,  2.766534 ,
#           7.8161983], dtype=float32), 'var51': ndarray([19.880056  ,  8.685799  ,  0.08505406, ..., 21.319778  ,
#          12.270927  , 16.96962   ], dtype=float32), 'var52': ndarray([20.823872,  8.589107,  5.270757, ..., 13.700161, 12.792498,
#           9.057484], dtype=float32), 'var53': ndarray([14.439025 , 11.1156435, 10.019882 , ..., 15.607148 , 16.852459 ,
#           8.542004 ], dtype=float32), 'var54': ndarray([ 7.0565014, 11.225058 ,  3.3800917, ...,  8.343663 ,  7.6205688,
#          13.245024 ], dtype=float32), 'var55': ndarray([ 6.845658 ,  4.279165 ,  8.603886 , ...,  3.6363654, 15.795469 ,
#          10.976359 ], dtype=float32), 'var56': ndarray([ 2.3825734 ,  1.7392768 , -0.43394586, ...,  4.272     ,
#          -0.63553256, -2.1715887 ], dtype=float32), 'var57': ndarray([ 0.955573  , -2.0293076 , -6.62277   , ..., -0.02371397,
#           2.9875531 ,  6.4500995 ], dtype=float32), 'var58': ndarray([ 8.580108 ,  7.872636 , -2.3768609, ..., 12.215817 , 10.3505535,
#          10.217226 ], dtype=float32), 'var59': ndarray([18.414095 , 12.204188 ,  6.3543816, ...,  9.916101 , 16.684275 ,
#           7.0814056], dtype=float32), 'var6': ndarray([ 1.4838611 , -0.17165855, 18.090895  , ...,  5.6802936 ,
#           4.511454  ,  4.279005  ], dtype=float32), 'var60': ndarray([15.436429 ,  9.268894 ,  2.3146772, ...,  7.296494 , 11.605844 ,
#           7.878999 ], dtype=float32), 'var61': ndarray([14.009829 ,  7.8593807,  1.5066624, ..., 19.305864 , 14.6042   ,
#          15.6061735], dtype=float32), 'var62': ndarray([ 7.3402386, -2.3586526,  2.8096406, ...,  7.768816 ,  7.263626 ,
#           7.2741246], dtype=float32), 'var63': ndarray([11.776831,  4.457062,  7.105893, ...,  6.051146, 17.479961,
#           9.918994], dtype=float32), 'var7': ndarray([-3.8706129 ,  1.7222944 , 11.104798  , ...,  4.873855  ,
#          -0.46532583,  0.945365  ], dtype=float32), 'var8': ndarray([ 3.5277545,  5.1762023,  6.3105745, ...,  3.2175465,  0.7049532,
#          -3.2432895], dtype=float32), 'var9': ndarray([ 1.0955719,  6.0525527,  6.063516 , ...,  5.6562095, -0.3369899,
#          -1.253625 ], dtype=float32)}

# %%
import numpy as np
import pandas as pd
res_array = []
# for i in range(64):
vec1 = df.AsNumpy(columns=["var1"])#+str(i)])   # test to get "vector", vector<double> branch
res1_array = np.array(list(vec1.values()))

print(vec1)

print(type(res1_array))
print(res1_array.shape)
res1_array.reshape(1,10000)
mylis = res1_array.tolist()

print(mylis)
# convert array into dataframe
DF = pd.DataFrame(res1_array)

# save the dataframe as a csv file
DF.to_csv("data1.csv")

DF.head()
# Out:
# {'var1': ndarray([0.7632829, 5.66362  , 1.4061441, ..., 8.663832 , 4.4268465,
#          1.2475878], dtype=float32)}
# <class 'numpy.ndarray'>
# (1, 10000)
# [[0.7632828950881958, 5.6636199951171875, 1.406144142150879, -0.9711433053016663, 7.293004989624023, 7.006859302520752, 2.1723930835723877, 6.329552173614502, 12.701866149902344, -2.0589334964752197, 9.26772403717041, 4.592174530029297, 3.96616792678833, 1.6131179332733154, 0.5532554984092712, 5.453526973724365, -0.4444558322429657, 5.936376571655273, 1.0321955680847168, 1.4384419918060303, 4.3762359619140625, 9.677103996276855, -0.9104033708572388, 10.74475383758545, 5.264432430267334, 7.280004978179932, -0.8317936658859253, 6.799129962921143, 3.653557300567627, 5.507087230682373, 10.816302299499512, -0.9599388241767883, 8.991710662841797, 3.0709731578826904, 2.6449131965637207, -1.7218074798583984, 2.186312675476074, 10.80774211883545, 0.8233423829078674, 4.745521545410156, 11.09861946105957, 1.1820310354232788, 6.2873454093933105, 1.9907331466674805, 4.890631198883057, 10.15976333618164, -0.5515946745872498, 8.994638442993164, 0.18809030950069427, -4.530184745788574, 3.215665340423584, 8.817365646362305, 5.540097236633301, -5.795873641967773, 2.931230306625366, 1.459936261177063, -1.1527504920959473, 5.085188865661621, 6.9759626388549805, -2.1655960083007812, 14.580853462219238, -7.80081844329834, -2.323415756225586, 6.437441825866699, 2.3510193824768066, 0.9753150939941406, -3.239875078201294, 5.205085754394531, 0.6298285126686096, 3.2568881511688232, 3.4047741889953613, 1.3900113105773926, -2.763866901397705, 6.7475481033325195, 5.0180864334106445, -0.16123807430267334, 7.9658918380737305, 1.590980052947998, 2.2420973777770996, 2.3816375732421875, 3.837012767791748, 8.782931327819824, 0.6497984528541565, 5.5849385261535645, 7.8602447509765625, 8.754622459411621, 16.584245681762695, -0.34347137808799744, 10.66226863861084, 6.412103652954102, 19.7857608795166, 4.204326629638672, 1.6773741245269775, 6.5017290115356445, 2.1893980503082275, 6.799557209014893, 8.629865646362305, 5.484785079956055, 0.9520017504692078, 3.543025493621826, 11.110867500305176, -4.016214847564697, -1.380829930305481, -1.5936148166656494, -1.214301347732544, 5.930517196655273, -1.405797004699707, -1.2172666788101196, 2.3943846225738525, 4.71308708190918, 3.9534263610839844, 0.4289921820163727, 2.1973929405212402, 13.580636024475098, 7.830970764160156, 7.308714389801025, -1.0985428094863892, 9.553565979003906, 5.373045921325684, 3.9613571166992188, 3.3163440227508545, 8.254358291625977, 6.910365104675293, 6.528995037078857, 4.799809455871582, 3.5642588138580322, 10.949328422546387, 2.6404623985290527, -0.2925048768520355, 10.431693077087402, 0.7167729139328003, 3.1367177963256836, 7.496805191040039, -0.1848275065422058, 5.175461292266846, 2.5558366775512695, 2.4299399852752686, 15.436861991882324, 2.504317283630371, 20.995437622070312, 11.69165325164795, 6.271914005279541, -0.6245623826980591, 4.184655666351318, 0.0955384373664856, -1.6651246547698975, -0.24712741374969482, 2.4078524112701416, 2.6777312755584717, 7.9024810791015625, 9.9830322265625, 7.299583911895752, 0.3643648028373718, 5.584271430969238, -5.192151069641113, 4.724244117736816, 0.8995866179466248, 8.589545249938965, 0.09407550096511841, 4.528440952301025, 8.761385917663574, 6.1298041343688965, 16.842727661132812, 4.199746131896973, 0.26510879397392273, 5.088863849639893, 8.801124572753906, 2.6053152084350586, 3.939934730529785, 5.982898235321045, 2.7814056873321533, 1.1168431043624878, 2.743288040161133, 9.776642799377441, 21.347026824951172, 1.9170001745224, 4.352367877960205, 1.7335693836212158, 6.292614936828613, 1.577246904373169, 5.796767711639404, 1.9260423183441162, -0.11694098263978958, 8.999825477600098, -2.857102394104004, 8.560754776000977, 4.152015209197998, 5.083671569824219, 6.83327054977417, 2.947547674179077, 9.26313591003418, 3.106066942214966, 6.787430286407471, -0.9514206051826477, 0.5617151856422424, 2.866166830062866, 6.538305282592773, -0.6898728013038635, 5.930562496185303, -7.801926612854004, 7.268400192260742, 0.662997305393219, 3.3574557304382324, -2.085682630 ...
#        0        1         2         3         4         5         6     \
# 0  0.763283  5.66362  1.406144 -0.971143  7.293005  7.006859  2.172393
#
#        7          8         9     ...      9990      9991      9992      9993  \
# 0  6.329552  12.701866 -2.058933  ... -0.321991  7.750695  2.559557  5.546951
#
#       9994      9995      9996      9997      9998      9999
# 0  5.50737 -2.732218 -0.123926  8.663832  4.426847  1.247588
#
# [1 rows x 10000 columns]

# %%
vec2 = df.AsNumpy(columns=["var2"])#+str(i)])   # test to get "vector", vector<double> branch
res2_array = np.array(list(vec2.values()))
print(vec2)

print(type(res2_array))
print(res2_array.shape)
res2_array.reshape(1,10000)
mylis1=res2_array.tolist()
print(res2_array)
print(mylis1)
# # convert array into dataframe
df1 = pd.DataFrame(res2_array)

# # save the dataframe as a csv file
# DF.to_csv("data.csv")
# DF.head()
df1.to_csv("data.csv",mode='a', index=False, header=False)
df1.head()
# Out:
# {'var2': ndarray([ 3.082547  , -1.8811955 ,  4.5406365 , ...,  3.6843252 ,
#           5.5426073 ,  0.95661587], dtype=float32)}
# <class 'numpy.ndarray'>
# (1, 10000)
# [[ 3.082547   -1.8811955   4.5406365  ...  3.6843252   5.5426073
#    0.95661587]]
# [[3.0825469493865967, -1.8811955451965332, 4.5406365394592285, 4.393821716308594, 8.129721641540527, 1.661800742149353, 6.799651145935059, 8.857415199279785, 9.923343658447266, 4.301283359527588, 17.28026008605957, 8.22297477722168, 7.40480899810791, 2.091951847076416, -0.3059543967247009, 11.236848831176758, 7.76162576675415, 9.115053176879883, 4.020849704742432, 3.7037265300750732, 13.305109977722168, 4.004326343536377, 0.5908134579658508, 9.068084716796875, 5.653715133666992, 20.554723739624023, 4.958134651184082, 9.005273818969727, 8.253056526184082, 3.886308431625366, 11.725221633911133, 2.6402130126953125, 9.074021339416504, 11.747851371765137, 7.029397964477539, 6.746233940124512, -2.1802685260772705, 9.433998107910156, -1.0315093994140625, 3.027738094329834, -1.078300952911377, -0.6997361183166504, 4.166722297668457, 7.57581090927124, 8.184138298034668, 7.477522373199463, -0.7416329383850098, 11.232142448425293, 5.81148099899292, 4.921299457550049, 4.414368629455566, 10.108442306518555, 11.610823631286621, -2.6532950401306152, -0.1337975710630417, 4.210395336151123, 1.7454766035079956, 14.411506652832031, 4.987627029418945, -2.073133707046509, 20.07468032836914, -3.871129035949707, 7.101775169372559, 4.685027599334717, -1.989137887954712, 3.4446861743927, -1.977218508720398, 4.866768836975098, 7.303165435791016, 1.595389485359192, 12.540781021118164, 2.4823145866394043, -4.0380539894104, 2.87396502494812, 5.228155136108398, 4.278092861175537, 4.457740783691406, 9.104748725891113, -1.0408143997192383, 3.82399582862854, 4.348730087280273, 13.039642333984375, 5.779458522796631, 4.351631164550781, -6.217176914215088, 7.3891754150390625, 14.66717529296875, 4.89210319519043, 4.620754718780518, 4.283792972564697, 15.730449676513672, 16.41878318786621, 5.295302391052246, 6.553760528564453, 4.124020576477051, 11.926154136657715, 2.687835931777954, 4.8320159912109375, 5.706313133239746, 5.2743635177612305, 4.842279434204102, 9.191204071044922, 12.534933090209961, 5.0041022300720215, 3.4500231742858887, 2.9899399280548096, -0.2834755480289459, 4.041779518127441, 5.952315330505371, 14.615683555603027, 11.095035552978516, 2.936908006668091, 3.329092264175415, 11.645976066589355, 5.0350565910339355, 6.847896575927734, 7.980998992919922, 5.50445556640625, -1.628263235092163, 10.440569877624512, -0.11538176983594894, 7.686615467071533, 4.238402843475342, 9.044455528259277, 18.588863372802734, 20.257171630859375, 11.197009086608887, 5.4041924476623535, 6.019935131072998, 8.260076522827148, 3.86730694770813, 3.7145721912384033, 8.682271003723145, 0.8529069423675537, 5.069226264953613, 5.543790817260742, 10.33132553100586, 11.959300994873047, 5.056480407714844, 17.532184600830078, 7.282646179199219, 4.014538764953613, -0.8098223209381104, 10.336236953735352, 4.318727970123291, 1.8347125053405762, -1.0128473043441772, 10.203129768371582, -0.32900744676589966, 10.971267700195312, 15.039162635803223, 13.86783504486084, 3.576990842819214, 11.243453979492188, 5.739773273468018, 2.8879940509796143, 7.582070827484131, 7.0011796951293945, 2.7594659328460693, 12.58042049407959, 8.408279418945312, 1.695503830909729, 10.906625747680664, 4.419419288635254, -1.4355287551879883, 5.574530124664307, 5.881389141082764, 7.5400004386901855, 0.23067490756511688, 11.56799602508545, -1.5096266269683838, 0.21056774258613586, 17.65737533569336, 0.8850876092910767, 10.936938285827637, 5.318765640258789, 2.627837657928467, 2.75382399559021, 8.077826499938965, 3.500457525253296, 3.5097594261169434, -1.7024015188217163, 5.926167964935303, 12.87079906463623, 7.236873626708984, 3.8041577339172363, 1.4535422325134277, 7.4760355949401855, 7.412877082824707, 5.07613468170166, 18.88865852355957, 2.142862319946289, 9.896437644958496, 13.037932395935059, -1.5574871301651, 1.6080842018127441, 6.091439723968506, 5.984870433807373, 0.8070048689842224, 2.521186351776123, 12.121502876281738, 0.8173118233680725, 3.378873586654663, 7.173106670379639, -3.766117811203003, 8.5259923 ...
#        0         1         2         3         4         5         6     \
# 0  3.082547 -1.881196  4.540637  4.393822  8.129722  1.661801  6.799651
#
#        7         8         9     ...      9990       9991      9992      9993  \
# 0  8.857415  9.923344  4.301283  ... -2.731176  17.805538  1.950762  8.029922
#
#         9994      9995      9996      9997      9998      9999
# 0  13.679983 -0.081861  5.230862  3.684325  5.542607  0.956616
#
# [1 rows x 10000 columns]

# %%
def generator(array1, array2 ,batch_size):
  inputs = []
  outputs = []
  batchcount = 0
  while True:
       for x in array1:
         inputs.append(x)
       for x1 in array2:
         outputs.append(x1)
         batchcount += 1
         if batchcount > batch_size:
                  X = np.array(inputs, dtype='float32')
                  y = np.array(outputs, dtype='float32')
                  yield (X,y)
                  inputs = []
                  outputs = []
                  batchcount = 0

# %%
#Total number of events in a Branch of a signal Tree
Nevents=10000

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten
model = Sequential()
model.add(Dense(12, input_dim=10000, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
model.add(Flatten())
model.summary()
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_29 (Dense)            (None, 12)                120012
#
#  dense_30 (Dense)            (None, 12)                156
#
#  dense_31 (Dense)            (None, 1)                 13
#
#  flatten_7 (Flatten)         (None, 1)                 0
#
# =================================================================
# Total params: 120,181
# Trainable params: 120,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# tf_ds = pd.read_csv("data1.csv")
# tf_ds2=pd.read_csv("data.csv")

model.fit(mylis,mylis1,batch_size=100, epochs=20)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 1s 525ms/step - loss: -11.9760 - accuracy: 0.0000e+00
# Epoch 2/20
# 1/1 [==============================] - 0s 7ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 3/20
# 1/1 [==============================] - 0s 9ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 4/20
# 1/1 [==============================] - 0s 9ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 5/20
# 1/1 [==============================] - 0s 13ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 6/20
# 1/1 [==============================] - 0s 10ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 7/20
# 1/1 [==============================] - 0s 10ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 8/20
# 1/1 [==============================] - 0s 6ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 9/20
# 1/1 [==============================] - 0s 10ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 10/20
# 1/1 [==============================] - 0s 6ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 11/20
# 1/1 [==============================] - 0s 6ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 12/20
# 1/1 [==============================] - 0s 7ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 13/20
# 1/1 [==============================] - 0s 12ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 14/20
# 1/1 [==============================] - 0s 7ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 15/20
# 1/1 [==============================] - 0s 8ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 16/20
# 1/1 [==============================] - 0s 6ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 17/20
# 1/1 [==============================] - 0s 11ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 18/20
# 1/1 [==============================] - 0s 7ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 19/20
# 1/1 [==============================] - 0s 9ms/step - loss: -73.5814 - accuracy: 0.0000e+00
# Epoch 20/20
# 1/1 [==============================] - 0s 12ms/step - loss: -73.5814 - accuracy: 0.0000e+00

# %%
batch_size=100

# %%
model.fit_generator(generator(mylis,mylis1,batch_size),steps_per_epoch=Nevents/batch_size ,epochs=20)
# Out:
# Epoch 1/20
# /tmp/ipykernel_9979/3615091883.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(generator(mylis,mylis1,batch_size),steps_per_epoch=Nevents/batch_size ,epochs=20)
# 100/100 [==============================] - 11s 102ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 2/20
# 100/100 [==============================] - 10s 100ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 3/20
# 100/100 [==============================] - 10s 100ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 4/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 5/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 6/20
# 100/100 [==============================] - 10s 100ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 7/20
# 100/100 [==============================] - 10s 102ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 8/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 9/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 10/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 11/20
# 100/100 [==============================] - 10s 100ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 12/20
# 100/100 [==============================] - 10s 100ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 13/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 14/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 15/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 16/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 17/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 18/20
# 100/100 [==============================] - 10s 100ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 19/20
# 100/100 [==============================] - 10s 100ms/step - loss: -73.5815 - accuracy: 0.0000e+00
# Epoch 20/20
# 100/100 [==============================] - 10s 101ms/step - loss: -73.5815 - accuracy: 0.0000e+00
